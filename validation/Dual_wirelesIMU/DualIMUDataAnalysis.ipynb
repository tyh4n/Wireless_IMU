# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from os import path
import math
import numpy as np
from scipy.signal import find_peaks
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib notebook

# %%
wirelessIMUDataPath = "imuData.csv"

# %%
#read data from wireless IMU recordings
wirelessIMUData = pd.read_csv(wirelessIMUDataPath)
wirelessIMUData["time"] = wirelessIMUData.index.to_numpy() / 100
#read data from PURE IMU rosbag

# %%
wirelessIMUData = wirelessIMUData[wirelessIMUData.index != 0]#remove first row
wirelessIMUData["angleDifference"] = wirelessIMUData.station - wirelessIMUData.wireless

# %%
fig,ax = plt.subplots(figsize=(6, 6))
ax.plot(wirelessIMUData.time,wirelessIMUData.station ,label='IMU1 Angle')
ax.plot(wirelessIMUData.time,wirelessIMUData.wireless ,label='IMU2 Angle')
ax.plot(wirelessIMUData.time,wirelessIMUData["diff"] ,label='Angle Difference')
ax.set_xlabel("Time(s)", fontsize = 14)
ax.set_ylabel("Sensor Data (deg)", fontsize = 14)
ax.legend(loc='upper left')
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="979.3333333333334">
